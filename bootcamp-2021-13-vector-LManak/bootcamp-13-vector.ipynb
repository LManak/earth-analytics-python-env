# %% [markdown]
# # Week 12 Spatial Vector Data Homework Template
#
# ## Assignment Background
#
# In this assignment, you will explore an area in California called the [San Joaquin Experimental Range](https://www.neonscience.org/field-sites/field-sites-map/SJER) known by the acronym SJER.
#
# The data that you will use for this week is available from **earthpy** using the following download:
#
# `et.data.get_data('spatial-vector-lidar')`
#
# To begin, add all of the needed package imports, download the data and set your working directory in the cells below.

# %%
# Autograding imports - do not modify this cell
import matplotcheck.notebook as nb
import matplotcheck.autograde as ag
import matplotcheck.vector as vct
import numpy as np
import pandas as pd

# This will hide one of geopandas warnings in cell 3
import warnings
warnings.filterwarnings('ignore',
                        'GeoSeries.notna',
                        UserWarning)

# %%
# Import packages, download data, and set working directory here
# import packages
# !pip install earthpy
# !pip install geopandas
# !pip install rioxarray
# !pip install rtree
# !pip install pygeos
# !pip install rasterio
# !pip install mapclassify

import os

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
import earthpy as et
from matplotlib.colors import ListedColormap
import xarray as xr
import rioxarray as rxr
import earthpy.plot as ep
from shapely.geometry import mapping

#download data
data = et.data.get_data("spatial-vector-lidar")

sjer_data_path = os.path.join(
    et.io.HOME,
    "earth-analytics",
    "data")

#test the directory
if os.path.exists(sjer_data_path):
    os.chdir(sjer_data_path)

else:
    print("The SJER directory does not exist")
# Out:
# Requirement already satisfied: earthpy in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (0.9.4)
# Requirement already satisfied: requests in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from earthpy) (2.25.1)
# Requirement already satisfied: numpy>=1.14.0 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from earthpy) (1.21.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from earthpy) (3.4.3)
# Requirement already satisfied: geopandas in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from earthpy) (0.10.0)
# Requirement already satisfied: rasterio in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from earthpy) (1.2.9)
# Requirement already satisfied: scikit-image in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from earthpy) (0.18.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from matplotlib>=2.0.0->earthpy) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from matplotlib>=2.0.0->earthpy) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from matplotlib>=2.0.0->earthpy) (8.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from matplotlib>=2.0.0->earthpy) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from matplotlib>=2.0.0->earthpy) (2.8.0)
# Requirement already satisfied: six in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from cycler>=0.10->matplotlib>=2.0.0->earthpy) (1.16.0)
# Requirement already satisfied: fiona>=1.8 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from geopandas->earthpy) (1.8.20)
# Requirement already satisfied: shapely>=1.6 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from geopandas->earthpy) (1.7.1)
# Requirement already satisfied: pandas>=0.25.0 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from geopandas->earthpy) (1.3.3)
# Requirement already satisfied: pyproj>=2.2.0 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from geopandas->earthpy) (3.2.1)
# Requirement already satisfied: attrs>=17 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from fiona>=1.8->geopandas->earthpy) (21.2.0)
# Requirement already satisfied: certifi in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from fiona>=1.8->geopandas->earthpy) (2021.5.30)
# Requirement already satisfied: click>=4.0 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from fiona>=1.8->geopandas->earthpy) (7.1.2)
# Requirement already satisfied: cligj>=0.5 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from fiona>=1.8->geopandas->earthpy) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from fiona>=1.8->geopandas->earthpy) (1.1.1)
# Requirement already satisfied: munch in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from fiona>=1.8->geopandas->earthpy) (2.5.0)
# Requirement already satisfied: setuptools in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from fiona>=1.8->geopandas->earthpy) (58.0.4)
# Requirement already satisfied: pytz>=2017.3 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from pandas>=0.25.0->geopandas->earthpy) (2021.1)
# Requirement already satisfied: snuggs>=1.4.1 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from rasterio->earthpy) (1.4.7)
# Requirement already satisfied: affine in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from rasterio->earthpy) (2.3.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from requests->earthpy) (1.25.11)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from requests->earthpy) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from requests->earthpy) (2.10)
# Requirement already satisfied: scipy>=1.0.1 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from scikit-image->earthpy) (1.7.1)
# Requirement already satisfied: networkx>=2.0 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from scikit-image->earthpy) (2.5)
# Requirement already satisfied: imageio>=2.3.0 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from scikit-image->earthpy) (2.9.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from scikit-image->earthpy) (2021.8.30)
# Requirement already satisfied: PyWavelets>=1.1.1 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from scikit-image->earthpy) (1.1.1)
# Requirement already satisfied: decorator>=4.3.0 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from networkx>=2.0->scikit-image->earthpy) (5.1.0)
# Requirement already satisfied: geopandas in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (0.10.0)
# Requirement already satisfied: pandas>=0.25.0 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from geopandas) (1.3.3)
# Requirement already satisfied: shapely>=1.6 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from geopandas) (1.7.1)
# Requirement already satisfied: fiona>=1.8 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from geopandas) (1.8.20)
# Requirement already satisfied: pyproj>=2.2.0 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from geopandas) (3.2.1)
# Requirement already satisfied: attrs>=17 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (21.2.0)
# Requirement already satisfied: certifi in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (2021.5.30)
# Requirement already satisfied: click>=4.0 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: cligj>=0.5 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: six>=1.7 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: munch in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: setuptools in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (58.0.4)
# Requirement already satisfied: numpy>=1.17.3 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from pandas>=0.25.0->geopandas) (1.21.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from pandas>=0.25.0->geopandas) (2.8.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from pandas>=0.25.0->geopandas) (2021.1)
# Requirement already satisfied: rioxarray in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (0.7.1)
# Requirement already satisfied: scipy in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from rioxarray) (1.7.1)
# Requirement already satisfied: packaging in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from rioxarray) (21.0)
# Requirement already satisfied: xarray>=0.17 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from rioxarray) (0.19.0)
# Requirement already satisfied: rasterio in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from rioxarray) (1.2.9)
# Requirement already satisfied: pyproj>=2.2 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from rioxarray) (3.2.1)
# Requirement already satisfied: certifi in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from pyproj>=2.2->rioxarray) (2021.5.30)
# Requirement already satisfied: pandas>=1.0 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from xarray>=0.17->rioxarray) (1.3.3)
# Requirement already satisfied: setuptools>=40.4 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from xarray>=0.17->rioxarray) (58.0.4)
# Requirement already satisfied: numpy>=1.17 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from xarray>=0.17->rioxarray) (1.21.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from pandas>=1.0->xarray>=0.17->rioxarray) (2.8.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from pandas>=1.0->xarray>=0.17->rioxarray) (2021.1)
# Requirement already satisfied: six>=1.5 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=1.0->xarray>=0.17->rioxarray) (1.16.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from packaging->rioxarray) (2.4.7)
# Requirement already satisfied: snuggs>=1.4.1 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from rasterio->rioxarray) (1.4.7)
# Requirement already satisfied: affine in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from rasterio->rioxarray) (2.3.0)
# Requirement already satisfied: click>=4.0 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from rasterio->rioxarray) (7.1.2)
# Requirement already satisfied: click-plugins in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from rasterio->rioxarray) (1.1.1)
# Requirement already satisfied: attrs in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from rasterio->rioxarray) (21.2.0)
# Requirement already satisfied: cligj>=0.5 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from rasterio->rioxarray) (0.7.2)
# Requirement already satisfied: rtree in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (0.9.7)
# Requirement already satisfied: pygeos in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (0.10.2)
# Requirement already satisfied: numpy>=1.13 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from pygeos) (1.21.2)
# Requirement already satisfied: rasterio in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (1.2.9)
# Requirement already satisfied: certifi in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from rasterio) (2021.5.30)
# Requirement already satisfied: click-plugins in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: attrs in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from rasterio) (21.2.0)
# Requirement already satisfied: setuptools in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from rasterio) (58.0.4)
# Requirement already satisfied: snuggs>=1.4.1 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from rasterio) (1.4.7)
# Requirement already satisfied: click>=4.0 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from rasterio) (7.1.2)
# Requirement already satisfied: affine in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from rasterio) (2.3.0)
# Requirement already satisfied: numpy in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from rasterio) (1.21.2)
# Requirement already satisfied: cligj>=0.5 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: pyparsing>=2.1.6 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from snuggs>=1.4.1->rasterio) (2.4.7)
# Requirement already satisfied: mapclassify in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (2.4.3)
# Requirement already satisfied: pandas>=1.0 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from mapclassify) (1.3.3)
# Requirement already satisfied: scipy>=1.0 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from mapclassify) (1.7.1)
# Requirement already satisfied: scikit-learn in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from mapclassify) (1.0)
# Requirement already satisfied: numpy>=1.3 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from mapclassify) (1.21.2)
# Requirement already satisfied: networkx in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from mapclassify) (2.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from pandas>=1.0->mapclassify) (2.8.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from pandas>=1.0->mapclassify) (2021.1)
# Requirement already satisfied: six>=1.5 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=1.0->mapclassify) (1.16.0)
# Requirement already satisfied: decorator>=4.3.0 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from networkx->mapclassify) (5.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from scikit-learn->mapclassify) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages (from scikit-learn->mapclassify) (1.0.1)

# %%
# DO NOT MODIFY THIS CELL
# Tests that the working directory is set to earth-analytics/data

path = os.path.normpath(os.getcwd())
student_wd_parts = path.split(os.sep)

wd_import_points = 0

if student_wd_parts[-2:] == ['earth-analytics', 'data']:
    print("\u2705 Great - it looks like your working directory is set correctly to ~/earth-analytics/data")
    wd_import_points += 4
else:
    print("\u274C Oops, the autograder will not run unless your working directory is set to earth-analytics/data")

print("\n \u27A1 You received {} out of 4 points for setting your working directory and imports.".format(
    wd_import_points))
wd_import_points
# Out:
# ✅ Great - it looks like your working directory is set correctly to ~/earth-analytics/data
#
#  ➡ You received 4 out of 4 points for setting your working directory and imports.
# 4

# %% [markdown]
# ## Challenge 1a: Open And Clip Your Vector Data
#
# The NEON **SJER** field site is located in California. Your first task is to explore the area by creating a map of California roads that has symbology that represents different road types.
#
# ### Open the roads layer and clip it using the SJER_crop extent
#
# In the cell below:
#
# 1. Open the `california/madera-county-roads/tl_2013_06039_roads.shp` file located in your `spatial-vector-lidar` data download using GeoPandas.
# 2. Reproject the roads data to be the same CRS as the area of interest. They should both have the CRS of `EPSG:32611`.
# 3. Clip the data using the SJER boundary (`california/neon-sjer-site/vector_data/SJER_crop.shp`) layer.
# 4. Open the SJER plot locations data (`california/neon-sjer-site/vector_data/SJER_plot_centroids.shp`).
# 5. Set all `RTTYP` that are "none" to "Unknown" using the syntax: `roads-object-name["RTTYP"].fillna("Unknown", inplace=True)`
#
# Call the **clipped and reprojected roads shapefile geodataframe object** at the
# end of the cell to ensure the tests below run.

# %%
# open the shp file
madera_roads_path = os.path.join("spatial-vector-lidar",
                                 "california", "madera-county-roads", 
                                 "tl_2013_06039_roads.shp")


madera_roads = gpd.read_file(madera_roads_path)
#madera_roads.head(5)

# reproject the roads data to be same CRS "EPSG:32611"

sjer_rds_locations_espg = madera_roads.to_crs({'init': 'epsg:32611'})
sjer_rds_locations_espg.crs

# Clip the data
SJER_crop_path = os.path.join("spatial-vector-lidar",
                                 "california", "neon-sjer-site", 
                                 "vector_data", "SJER_crop.shp")
SJER_crop = gpd.read_file(SJER_crop_path)
clipped_roads = gpd.clip(sjer_rds_locations_espg, SJER_crop)

# Open the SJER plot locations data

SJER_plot_path = os.path.join("spatial-vector-lidar",
                                 "california", "neon-sjer-site", 
                                 "vector_data", "SJER_plot_centroids.shp")
SJER_plot = gpd.read_file(SJER_plot_path)
print(SJER_plot)

# Set all RTTYP that are none to unknown
clipped_roads["RTTYP"].fillna("Unknown", inplace=True)
clipped_roads
# Out:
# /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
#      Plot_ID   Point     northing     easting plot_type  \
# 0   SJER1068  center  4111567.818  255852.376     trees
# 1    SJER112  center  4111298.971  257406.967     trees
# 2    SJER116  center  4110819.876  256838.760     grass
# 3    SJER117  center  4108752.026  256176.947     trees
# 4    SJER120  center  4110476.079  255968.372     grass
# 5    SJER128  center  4111388.570  257078.867     trees
# 6    SJER192  center  4111071.087  256683.434     grass
# 7    SJER272  center  4112167.778  256717.467     trees
# 8   SJER2796  center  4111533.879  256034.390      soil
# 9   SJER3239  center  4109856.983  258497.102      soil
# 10    SJER36  center  4110161.674  258277.829     trees
# 11   SJER361  center  4107527.074  256961.794     grass
# 12    SJER37  center  4107578.841  256148.197     trees
# 13     SJER4  center  4109767.289  257228.336     trees
# 14     SJER8  center  4110249.265  254738.618     trees
# 15   SJER824  center  4110047.586  256185.584      soil
# 16   SJER916  center  4109616.679  257460.486      soil
# 17   SJER952  center  4110759.039  255871.194     grass
#
#                           geometry
# 0   POINT (255852.376 4111567.818)
# 1   POINT (257406.967 4111298.971)
# 2   POINT (256838.760 4110819.876)
# 3   POINT (256176.947 4108752.026)
# 4   POINT (255968.372 4110476.079)
# 5   POINT (257078.867 4111388.570)
# 6   POINT (256683.434 4111071.087)
# 7   POINT (256717.467 4112167.778)
# 8   POINT (256034.390 4111533.879)
# 9   POINT (258497.102 4109856.983)
# 10  POINT (258277.829 4110161.674)
# 11  POINT (256961.794 4107527.074)
# 12  POINT (256148.197 4107578.841)
# 13  POINT (257228.336 4109767.289)
# 14  POINT (254738.618 4110249.265)
# 15  POINT (256185.584 4110047.586)
# 16  POINT (257460.486 4109616.679)
# 17  POINT (255871.194 4110759.039)
#            LINEARID                FULLNAME    RTTYP  MTFCC  \
# 2189   110454253913                    None  Unknown  S1400
# 5606   110454253912                    None  Unknown  S1400
# 6742   110454253914                    None  Unknown  S1400
# 2167   110454253911                    None  Unknown  S1400
# 6717   110454253910                    None  Unknown  S1400
# 5587   110454253909                    None  Unknown  S1400
# 7879   110454245219               O'Neal Rd        M  S1400
# 6718   110454238841                  211 Rd        M  S1400
# 6716   110454254255                    None  Unknown  S1400
# 311    110454242886        Old Oak Stage Pl        M  S1400
# 6715   110454255291                    None  Unknown  S1400
# 2168   110454253897                    None  Unknown  S1400
# 5588   110454255293                    None  Unknown  S1400
# 4369   110454253898                    None  Unknown  S1400
# 4368   110454255017                    None  Unknown  S1400
# 2059   110454255018                    None  Unknown  S1400
# 2061   110454255021                    None  Unknown  S1400
# 5491   110454255025                    None  Unknown  S1400
# 8951   110454255024                    None  Unknown  S1400
# 8950   110454253908                    None  Unknown  S1400
# 5493   110454244509        Bates Station Rd        M  S1400
# 7788   110454238898                  Rd 406        M  S1400
# 6739   110454253936                    None  Unknown  S1400
# 1017   110454253915                    None  Unknown  S1400
# 6740   110454253937                    None  Unknown  S1400
# 7895   110454253938                    None  Unknown  S1400
# 8751  1104468825854            State Hwy 41        S  S1200
# 9047   110454243802          Jewel Vista Dr        M  S1400
# 7028   110454253016                    None  Unknown  S1400
# 4707   110454253069                    None  Unknown  S1400
# 6622   110454239218                 Rd 8063        M  S1400
# 6621   110454253032                    None  Unknown  S1400
# 5494   110454255030                    None  Unknown  S1400
# 4370   110454255031                    None  Unknown  S1400
# 9384   110454255041                    None  Unknown  S1400
# 1112   110454253894                    None  Unknown  S1400
# 6839   110454253896                    None  Unknown  S1400
# 9173   110454253895                    None  Unknown  S1400
# 5495   110454255042                    None  Unknown  S1400
# 2449   110454253070                    None  Unknown  S1400
# 3624   110454253071                    None  Unknown  S1400
# 2450   110454255566                    None  Unknown  S1400
# 2438   110454245165  Outback Industrial Way        M  S1400
# 2452   110454255848                    None  Unknown  S1400
# 7004   110454253096                    None  Unknown  S1400
# 4706   110454255849                    None  Unknown  S1400
# 6419  1104258031278            State Rte 41        S  S1200
# 2016   110454238820                  Rd 200        M  S1200
# 45     110454239306               N Fork Rd        M  S1200
#
#                                                geometry
# 2189  LINESTRING (258166.923 4108351.911, 258165.443...
# 5606  LINESTRING (258166.923 4108351.911, 258196.856...
# 6742  LINESTRING (258068.216 4108434.372, 258077.141...
# 2167  LINESTRING (258110.740 4108527.332, 258108.670...
# 6717  LINESTRING (257983.127 4108743.339, 257976.016...
# 5587  LINESTRING (257983.127 4108743.339, 258001.855...
# 7879  LINESTRING (257423.271 4107303.077, 257414.988...
# 6718  LINESTRING (257423.271 4107303.077, 257414.988...
# 6716  LINESTRING (258726.876 4109197.037, 258677.968...
# 311   LINESTRING (258867.409 4109636.978, 258866.813...
# 6715  LINESTRING (258436.586 4110705.994, 258408.911...
# 2168  LINESTRING (258224.931 4111150.752, 258214.627...
# 5588  LINESTRING (258224.931 4111150.752, 258241.188...
# 4369  LINESTRING (256065.990 4107303.077, 256061.562...
# 4368  LINESTRING (256711.652 4107303.077, 256724.805...
# 2059  LINESTRING (256454.331 4107303.077, 256452.671...
# 2061  LINESTRING (255606.645 4107675.793, 255643.956...
# 5491  LINESTRING (256175.266 4107926.449, 256314.380...
# 8951  LINESTRING (256175.266 4107926.449, 256143.156...
# 8950  LINESTRING (257412.929 4108582.242, 257413.557...
# 5493  LINESTRING (255506.820 4108929.033, 255480.727...
# 7788  LINESTRING (255506.820 4108929.033, 255480.727...
# 6739  LINESTRING (258393.406 4107670.066, 258408.964...
# 1017  LINESTRING (257900.762 4107661.752, 257904.069...
# 6740  LINESTRING (258393.406 4107670.066, 258366.372...
# 7895  LINESTRING (258867.409 4107693.343, 258814.347...
# 8751  LINESTRING (254775.557 4107303.077, 254791.165...
# 9047  LINESTRING (254570.567 4107937.842, 254572.533...
# 7028  LINESTRING (255060.079 4108069.811, 254989.742...
# 4707  LINESTRING (255072.082 4111879.731, 255062.326...
# 6622  LINESTRING (257646.165 4108540.554, 257632.367...
# 6621  LINESTRING (255506.820 4108929.033, 255535.287...
# 5494  LINESTRING (257947.495 4108775.903, 257939.449...
# 4370  LINESTRING (255672.200 4109005.428, 255703.905...
# 9384  LINESTRING (256047.646 4110143.617, 256027.106...
# 1112  LINESTRING (256577.679 4110296.113, 256544.130...
# 6839  LINESTRING (256843.264 4110344.536, 256815.721...
# 9173  LINESTRING (256577.679 4110296.113, 256580.975...
# 5495  LINESTRING (256843.264 4110344.536, 256890.998...
# 2449  LINESTRING (255993.449 4110213.489, 256004.106...
# 3624  MULTILINESTRING ((255993.449 4110213.489, 2559...
# 2450  LINESTRING (256410.586 4111756.860, 256414.803...
# 2438  LINESTRING (257764.669 4111791.796, 257709.492...
# 2452  LINESTRING (254993.084 4112178.792, 254942.733...
# 7004  LINESTRING (254570.567 4112153.393, 254581.960...
# 4706  LINESTRING (254993.084 4112178.792, 254984.967...
# 6419  LINESTRING (254775.557 4107303.077, 254791.165...
# 2016  LINESTRING (256848.128 4112181.255, 256898.607...
# 45    LINESTRING (256848.128 4112181.255, 256898.607...

# %%
# DO NOT MODIFY THIS CELL

# %% [markdown]
# ## Challenge 1b: Create a Figure Of Your Study Area
#
# In the cell below, add code to create your challenge figure using the
# objects that you generated above.
#
# Create a map that shows the madera roads layer, SJER plot locations and the SJER boundary (`california/neon-sjer-site/vector_data/SJER_crop.shp`). All data should be cropped to your
# SJER boundary crop extent (your Area Of Interest or AOI)
#
# ### Important Notes For Your Figure
#
# 1. Plot the roads so different **road types** are represented using unique symbology using the `RTTYP` attribute.
# 2. Add the plot locations to your map. Color each location according to the attribute **plot type** using unique symbology for each `plot_type` in the data.
# 3. Add a **title** to your figure.
# 4. Be sure that your plot legend is not covering your final map.
# 5. **IMPORTANT:** be sure that all of the data are cropped to the **same spatial extent**
# and **crs**. This means that you have to clip and reproject your data prior to plotting it.

# %%
# Create a symbology dictionary that maps "type" to color. In this case the types are trees, grass and soil
points_symb = {'trees': 'chartreuse',
               'grass': 'darkgreen',
               'soil': 'burlywood'}

road_symb = {'M': 'maroon',
             'S': 'goldenrod',
             'Unknown': 'darkslategrey'}

# PLOT 1 - Place only the code required to create a plot of your data here
fig, ax = plt.subplots(figsize=(5, 5))
ax.set_axis_off()
fig.suptitle('San Joaquin Experiemental Range(SJER) Map', 
             fontsize=20, fontweight='bold')

SJER_plot.plot(ax=ax, facecolor="none", edgecolor="black")

# Add the plot points in sets grouped by plot_type
for plot_type, SJER_plot_gdf in SJER_plot.groupby('plot_type'):
   SJER_plot_gdf.plot(ax=ax,
                  color=points_symb[plot_type],
                  label=plot_type)

# Add roads in sets grouped by road type using RTTYP attribute
for RTTYP, sjer_rds_gdf in clipped_roads.groupby('RTTYP'):
    sjer_rds_gdf.plot(ax=ax,
                      color=road_symb[RTTYP],
                      label=RTTYP)

# Add a legend
plt.legend(bbox_to_anchor=(1.4,1), borderaxespad=0)

### DO NOT REMOVE LINE BELOW ###
plot01_roads_plot_locs = nb.convert_axes(plt, which_axes="current")

# %%
# DO NOT MODIFY THIS CELL

# %% [markdown]
# ### Figure 1 - Manual Points -
# * Points for plot title being expressive

# %% [markdown]
# ## Question (5 points)
#
# What does the RTTYP road type acronyms **M** and **S** stand for?
# Please your answer in the markdown cell BELOW.
#
# HINT: use the `tl_2013_06039_roads.shp.xml` file in your data download to help you figure out the answer to this question
# HINT2: you can also find good results using Google (on the column name)!

# %% [markdown]
# The RTTYP road type acronyms "M", and "S" stand for M= Common name, and S= state recognized.

# %% [markdown]
# ## Challenge 2: Figure 2 - Roads in Del Norte, Modoc & Siskiyou Counties
#
# Create a plot of roads that are located in: Del Norte, Modoc & Siskiyou Counties. To do this, you will need the following layers:
#
# * Counties in California: `california/CA_Counties/CA_Counties_TIGER2016.shp`
# * Roads: `spatial-vector-lidar/global/ne_10m_roads/ne_10m_roads.shp`
#
# To create this plot, you will need to:
#
# 1. Reproject the roads and the county data to `epsg=5070`
# 2. Select the three counties that you want to work with in the counties dataset. One fast way to do this is using syntax as follows:
#
# `roads_df[roads_df['NAME'].isin(["Siskiyou", "Modoc", "Del Norte"])]`
#
# 3. Clip the roads data to the boundary of the counties that you wish to look at.
# 4. Assign each road segment an attribute that identifies it as within each county.
#
# Color the roads in each county using a unique color.
#
# HINT: use the `legend=True` argument in `.plot()` to create a legend.
# Because you are only creating a legend for one layer, you can quickly use `.plot()`
# rather than `ax.legend()` which is what you used to create the figure above.
#
#
# ### IMPORTANT:
#
# * Both layers need to the in the SAME coordinate reference system for you to work with them together. REPROJECT both data layers to albers `.to_crs(epsg=5070)`
# * Clip the roads to the boundary of the three_counties layer that you created which only contains the 3 selected counties: `"Siskiyou", "Modoc", "Del Norte"`
# * To assign each road to its respective county, you will perform a spatial join using `.sjoin()`.
# * You will need to redefine the CRS of the roads layer, after the clip, which you can do using something like:
#
# ```county_roads.crs = ca_cty_albers.crs```
#
# **NOTE:** you can ignore the warning from pyproj: `'+init=<authority>:<code>' syntax is deprecated.`, which will be resolved by GeoPandas in the next release.

# %% [markdown]
# In the cell below, add the code needed to
#
# * Open each layer
# * Reproject the data
# * Clip and subset the data
#
# At the end of the cell, be sure to call the clipped roads layer.

# %%
# In this cell, add the code needed to open, reproject and clip / subset the data
# open the shp file
CA_counties_path = os.path.join("spatial-vector-lidar",
                                 "california", "CA_Counties", 
                                 "CA_Counties_TIGER2016.shp")


CA_counties = gpd.read_file(CA_counties_path)
#print(CA_counties)

roads_path = os.path.join("spatial-vector-lidar",
                          "global", "ne_10m_roads", 
                          "ne_10m_roads.shp")

CA_roads = gpd.read_file(roads_path)
#print(CA_roads)

# reproject the roads & data to be same CRS "epsg=5070

roads_df = CA_roads.to_crs(epsg=5070)
counties_df = CA_counties.to_crs(epsg=5070)
#roads_df.plot()
#plt.show()

# Clip the roads data to the boundary of the counties that you wish to look at.

clipped_roads = gpd.clip(counties_df[
    counties_df['NAME'].isin(["Siskiyou", "Modoc", "Del Norte"])], roads_df)
#clipped_roads.head(3)

#clipped_roads.plot()
#plt.show()


#Assign each road segment an attribute 

assigned_roads = gpd.sjoin(clipped_roads, 
                           counties_df.reset_index().to_crs(roads_df.crs), 
                           how = "inner", 
                           op = 'intersects')

county_roads_assigned = assigned_roads.to_crs({'init': 'epsg:5070'})
county_roads_assigned.head(3)


# YOUR CODE HERE
# Out:
# /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3364: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if (await self.run_code(code, result,  async_=asy)):
# /Users/leahmanak/opt/miniconda3/envs/earth-analytics-python/lib/python3.8/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
#    STATEFP_left COUNTYFP_left COUNTYNS_left GEOID_left NAME_left  \
# 35           06           049      00277289      06049     Modoc
# 54           06           093      00277311      06093  Siskiyou
# 54           06           093      00277311      06093  Siskiyou
#
#       NAMELSAD_left LSAD_left CLASSFP_left MTFCC_left CSAFP_left  ...  \
# 35     Modoc County        06           H1      G4020       None  ...
# 54  Siskiyou County        06           H1      G4020       None  ...
# 54  Siskiyou County        06           H1      G4020       None  ...
#
#    CLASSFP_right MTFCC_right CSAFP_right  CBSAFP_right  METDIVFP_right  \
# 35            H1       G4020        None          None            None
# 54            H1       G4020         454         39820            None
# 54            H1       G4020        None          None            None
#
#    FUNCSTAT_right  ALAND_right AWATER_right  INTPTLAT_right  INTPTLON_right
# 35              A  10140955630    745425201     +41.5929185    -120.7183704
# 54              A   9778179454    186530168     +40.7605142    -122.0435556
# 54              A  16261974847    179108278     +41.5879861    -122.5332868
#
# [3 rows x 37 columns]

# %%
student_three_counties = _

three_counties_points = 0

if isinstance(student_three_counties, gpd.geodataframe.GeoDataFrame):
    print("\u2705 Great! Your clipped object is a GeoDataFrame!")
    three_counties_points += 1
else:
    print("\u274C Oops, your clipped object is not a GeoDataFrame.")

if student_three_counties.crs.to_epsg() == 5070:
    print("\u2705 Great! Your clipped object has the correct CRS!")
    three_counties_points += 2
else:
    print("\u274C Oops, your clipped object does not have the correct CRS.")
# Out:
# ✅ Great! Your clipped object is a GeoDataFrame!
# ✅ Great! Your clipped object has the correct CRS!

# %%
# DO NOT MODIFY THIS CELL

# %% [markdown]
# ## Challenge 2b: Figure
#
# In the cell beloow,  add code to create the figure described above.

# %%
# Figure 2 - Place only the code required to plot your data here
# Additional processing code can go above this code cell
#assigning attributes to code

roads_symb = {'Siskiyou': 'purple',
              'Modoc': 'green',
              'Del Norte': 'goldenrod'}
#figure code
fig, ax = plt.subplots(figsize=(10, 10))
ax.set_axis_off()
fig.suptitle('Major Roads in Three California Counties', 
             fontsize=15, fontweight='bold')


county_roads_assigned.plot(ax=ax, 
                           facecolor="none", 
                           edgecolor="black", 
                           legend=True)

for county_roads, assigned_rd_df in assigned_roads.groupby('NAME_left'):
   assigned_rd_df.plot(ax=ax,
                       legend=True,
                       color=roads_symb[county_roads],
                       label=county_roads)

ax.legend()
#My legend=True function in .plot() didn't work, so I used the ax.legend to have it show up.


### DO NOT REMOVE LINE BELOW ###
plot02_county_roads_clip = nb.convert_axes(plt, which_axes="current")

# %%
# DO NOT MODIFY THIS CELL
hw_plot2 = vct.VectorTester(plot02_county_roads_clip)


plot_title = ag.run_test(hw_plot2.assert_title_contains,
                         strings_expected='',
                         points=1,
                         correct_message="\u2705 Plot title exists!",
                         error_message="\u274C Check your plot title exists.")

print(plot_title['message'])
# Out:
# ✅ Plot title exists!

# %% [markdown]
# ## Challenge 3:  Calculate Total Length of Road Siskiyou, Modoc, Del Norte County in California
#
# Create a dataframe that shows the total length of road in these counties used in plot 2: Siskiyou, Modoc, and Del Norte. To calculate this, use the data you created for plot 2.
#
# To calculate length of each line in your geodataframe, you can use the syntax `gdf.length`. Create a new column using the syntax:
#
# `gdf["length"] = gdf.length`
#
# You can summarize the data to calculate total length using pandas `.groupby()` on the county column name.
#
# Note: you can use: `pd.options.display.float_format = '{:.4f}'.format` if you'd like to turn off scientific notation for your outputs.
#
# It should look something like this:
#
#
# ||length|
# |----|----|
# |NAME||
# |Del Norte| road length here|
# |Modoc| road length here|
# |Siskiyou| road length here|
#
#
# At the end of the cell, call the dataframe object

# %%
# TABLE 1 - Place the code required to create the dataframe

assigned_rd_df["length"] = assigned_rd_df.length

assigned_rd_df
# Out:
#    STATEFP_left COUNTYFP_left COUNTYNS_left GEOID_left NAME_left  \
# 54           06           093      00277311      06093  Siskiyou
# 54           06           093      00277311      06093  Siskiyou
# 54           06           093      00277311      06093  Siskiyou
#
#       NAMELSAD_left LSAD_left CLASSFP_left MTFCC_left CSAFP_left  ...  \
# 54  Siskiyou County        06           H1      G4020       None  ...
# 54  Siskiyou County        06           H1      G4020       None  ...
# 54  Siskiyou County        06           H1      G4020       None  ...
#
#    MTFCC_right CSAFP_right CBSAFP_right  METDIVFP_right  FUNCSTAT_right  \
# 54       G4020         454        39820            None               A
# 54       G4020        None         None            None               A
# 54       G4020        None         None            None               A
#
#     ALAND_right AWATER_right INTPTLAT_right  INTPTLON_right      length
# 54   9778179454    186530168    +40.7605142    -122.0435556 472427.9500
# 54  16261974847    179108278    +41.5879861    -122.5332868 472427.9500
# 54   8234265201     73407949    +40.6477241    -123.1144043 472427.9500
#
# [3 rows x 38 columns]

# %%
# DO NOT MODIFY THIS CELL
# Test that the cali_roads_summary is of type dataframe and named correctly

# Let's make sure you created an object with the correct name and of the correct type above!

student_length_dataframe = _

length_points = 0

if len(student_length_dataframe) == 3:
    print("\u2705 Correct number of entries in the dataframe, good job!")
    length_points += 2
else:
    print("\u274C Incorrect amount of entries in the dataframe.")

if student_length_dataframe.length.dtype == 'float':
    print("\u2705 Length column has the correct datatype!")
    length_points += 2
else:
    print("\u274C Length column does not have the correct datetype.")
# Out:
# ✅ Correct number of entries in the dataframe, good job!
# ✅ Length column has the correct datatype!

# %%
# DO NOT MODIFY THIS CELL

# %% [markdown]
# ## Challenge 4: Plot 3 - Global  Estimated Population
#
# Create a plot of quantile maps of the sum of global estimated population by region. To do this, you will use the  natural earth data of global political boundaries. This can be found inside of the `spatial-vector-lidar` data downloaded at the start of this assignment. The country data is missing from the earthpy download, so you will need to download it separately, by putting the url directly into `gpd.read_file()`. The url to download country data is:
# `https://naturalearth.s3.amazonaws.com/110m_cultural/ne_110m_admin_0_countries.zip`
#
# After you have downloaded the data, import the data and
# 1. subset the data to include the following columns: `["REGION_WB", "POP_EST", 'geometry']`
# 2. Dissolve the data by region (`REGION_WB`) column and aggregate by `sum`.
#     * HINT: you can provide the aggfun= argument with a `[list]` of function names in quotes and it will summarize numeric columns using each function.
# 3. Create a figure that shows the sum of estimated population (`POP_EST`) by region.
#
# **NOTE:** you can ignore the warning from merge: `UserWarning: merging between different levels can give an unintended result`.

# %% [markdown]
# In the cell below:
#
# * Open up the data
# * Subset the columns needed using `dataframe[["column-1", "column-2", "column-3"]]`
# * use the `dissolve` function to dissolve the data by the `REGION_WB` column
#
# Call your final dissolved geodataframe at the end of the cell

# %%
#download data
country_data = gpd.read_file(
    "https://naturalearth.s3.amazonaws.com/110m_cultural/ne_110m_admin_0_countries.zip")
#country_data
#country_data.crs

#subset the data to include new columns
country_pop_geom = country_data[["REGION_WB", "POP_EST", "geometry"]]
country_pop_geom

#dissolve the data by region and aggregate by sum

region_sum = country_pop_geom.dissolve(by="REGION_WB", aggfunc=sum)
region_sum
# Out:
#                                                                      geometry  \
# REGION_WB
# Antarctica                  MULTIPOLYGON (((-61.13898 -79.98137, -60.61012...
# East Asia & Pacific         MULTIPOLYGON (((172.79858 -40.49396, 173.02037...
# Europe & Central Asia       MULTIPOLYGON (((-53.77852 2.37670, -54.08806 2...
# Latin America & Caribbean   MULTIPOLYGON (((-58.05000 -51.90000, -59.40000...
# Middle East & North Africa  MULTIPOLYGON (((51.17252 15.17525, 49.57458 14...
# North America               MULTIPOLYGON (((-155.54211 19.08348, -155.6881...
# South Asia                  MULTIPOLYGON (((80.34836 5.96837, 79.87247 6.7...
# Sub-Saharan Africa          MULTIPOLYGON (((68.72000 -49.24250, 68.86750 -...
#
#                                POP_EST
# REGION_WB
# Antarctica                        4050
# East Asia & Pacific         2286526185
# Europe & Central Asia        914635466
# Latin America & Caribbean    629275677
# Middle East & North Africa   431380808
# North America                362249471
# South Asia                  1731364127
# Sub-Saharan Africa          1027653678

# %%
# DO NOT MODIFY THIS CELL
student_dissolve_dataframe = _

dissolve_points = 0

if len(student_dissolve_dataframe) == 8:
    print("\u2705 Correct number of entries in the dataframe, good job!")
    dissolve_points += 2
else:
    print("\u274C Incorrect amount of entries in the dataframe.")

if isinstance(student_dissolve_dataframe, gpd.GeoDataFrame):
    print("\u2705 Data is stored in a GeoDataFrame, good job!")
    dissolve_points += 2
else:
    print("\u274C Data is not stored in a GeoDataFrame.")

print("\n \u27A1 You received {} out of 4 points.".format(
    dissolve_points))
dissolve_points
# Out:
# ✅ Correct number of entries in the dataframe, good job!
# ✅ Data is stored in a GeoDataFrame, good job!
#
#  ➡ You received 4 out of 4 points.
# 4

# %%
# PLOT 3 - Place only the code required to plot your data here
# Additional processing code can go above this code cell

#Figure code
fig, ax1 = plt.subplots(figsize=(10, 10))
ax1.set_axis_off()

region_sum.plot(column='POP_EST',
                 legend=True,
                 scheme="quantiles",
                 ax=ax1)

plt.suptitle('Population Estimate by Region', fontsize=15)
plt.axis('equal')
### DO NOT REMOVE LINE BELOW ###
plot04_global_population = nb.convert_axes(plt, which_axes="current")

# %%
# DO NOT MODIFY THIS CELL

# %%
# DO NOT MODIFY THIS CELL

hw_plot4_rank = vct.VectorTester(plot04_global_population)

results = []

plot_title_rank = ag.run_test(hw_plot4_rank.assert_title_contains,
                              strings_expected='',
                              points=1,
                              correct_message="\u2705 Plot title exists!",
                              error_message="\u274C Check that your plot title exists.")

# %% [markdown]
# ## Manual points for geometries in plot

# %% [markdown]
# ## Do not modify this cell (10 points)
#
# * Here we will grade pep8 format and imports listed at the top following pep 8 conventions.
# * Notebook begins with cell [1] and runs without modifications.
# * Be sure that your code can be run on any operating system. This means that:
#     * the data should be downloaded in the notebook to ensure it's reproducible
#     * all paths should be created dynamically using the os package to ensure that they work across operating systems
